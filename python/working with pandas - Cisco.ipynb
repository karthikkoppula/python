# %%
## Initial Data inspection steps

1. structure of the data - info, columns, index, shape, dtypes..
2. first few rows/last few rows
3. describe - descriptive stats
4. for categorial variables - unique values, unique count and frequecy
5. null values
6. duplicates

# %%
import pandas as pd

# %%
pwd()  # present working directory
# Out:
# '/voc/work'

# %%
pd.read_excel("/voc/work/cars.xlsx")
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
pd.read_excel("cars.xlsx")
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars = pd.read_excel("cars.xlsx")

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    int64
#  6   Invoice      428 non-null    int64
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 50.3+ KB

# %%
cars.shape
# Out:
# (428, 15)

# %%
cars.shape[0]
# Out:
# 428

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=428, step=1)

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
cars.describe()
# Out:
#                 MSRP        Invoice  EngineSize   Cylinders  Horsepower  \
# count     428.000000     428.000000  428.000000  426.000000  428.000000
# mean    32774.855140   30014.700935    3.196729    5.807512  215.885514
# std     19431.716674   17642.117750    1.108595    1.558443   71.836032
# min     10280.000000    9875.000000    1.300000    3.000000   73.000000
# 25%     20334.250000   18866.000000    2.375000    4.000000  165.000000
# 50%     27635.000000   25294.500000    3.000000    6.000000  210.000000
# 75%     39205.000000   35710.250000    3.900000    6.000000  255.000000
# max    192465.000000  173560.000000    8.300000   12.000000  500.000000
#
#          MPG_City  MPG_Highway       Weight   Wheelbase      Length
# count  428.000000   428.000000   428.000000  428.000000  428.000000
# mean    20.060748    26.843458  3577.953271  108.154206  186.362150
# std      5.238218     5.741201   758.983215    8.311813   14.357991
# ...

# %%
cars.head()
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
# 3  Acura           TL 4dr  Sedan   Asia      Front  33195    30299
# 4  Acura       3.5 RL 4dr  Sedan   Asia      Front  43755    39014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
cars.head(3)
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura          TSX 4dr  Sedan   Asia      Front  26990    24647
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183

# %%
cars.tail()
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 423    38203         2.4        5.0         197        21           28
# 424    40083         2.3        5.0         242        20           26
# 425    42573         2.9        6.0         268        19           26
# 426    24641         1.9        4.0         170        22           29
# 427    33112         2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 423    3450        105     186
# 424    3450        105     186
# ...

# %%
cars.tail(10)
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 418  Volvo               S60 2.5 4dr  Sedan  Europe        All  31745
# 419  Volvo                S60 T5 4dr  Sedan  Europe      Front  34845
# 420  Volvo                 S60 R 4dr  Sedan  Europe        All  37560
# 421  Volvo               S80 2.9 4dr  Sedan  Europe      Front  37730
# 422  Volvo              S80 2.5T 4dr  Sedan  Europe        All  37885
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 418    29916         2.5        5.0         208        20           27
# ...

# %%
Task

Find top 5 Makes according to their frequency in the data

# %%
cars.Make.value_counts()[:5].index
# Out:
# Index(['Toyota', 'Chevrolet', 'Mercedes-Benz', 'Ford', 'BMW'], dtype='object')

# %%
Task

Subset cars data for those cars with origin from either Europe or USA.

# %%
cars[(cars.Origin == 'Europe') | (cars.Origin == 'USA')]
# Out:
#       Make                       Model   Type  Origin DriveTrain   MSRP  \
# 7     Audi                 A4 1.8T 4dr  Sedan  Europe      Front  25940
# 8     Audi      A41.8T convertible 2dr  Sedan  Europe      Front  35940
# 9     Audi                  A4 3.0 4dr  Sedan  Europe      Front  31840
# 10    Audi   A4 3.0 Quattro 4dr manual  Sedan  Europe        All  33430
# 11    Audi     A4 3.0 Quattro 4dr auto  Sedan  Europe        All  34480
# ..     ...                         ...    ...     ...        ...    ...
# 423  Volvo     C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo     C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                  S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                         V40  Wagon  Europe      Front  26135
# 427  Volvo                        XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.loc[(cars.Origin == 'Europe') | (cars.Origin == 'USA'),:]
# Out:
#       Make                       Model   Type  Origin DriveTrain   MSRP  \
# 7     Audi                 A4 1.8T 4dr  Sedan  Europe      Front  25940
# 8     Audi      A41.8T convertible 2dr  Sedan  Europe      Front  35940
# 9     Audi                  A4 3.0 4dr  Sedan  Europe      Front  31840
# 10    Audi   A4 3.0 Quattro 4dr manual  Sedan  Europe        All  33430
# 11    Audi     A4 3.0 Quattro 4dr auto  Sedan  Europe        All  34480
# ..     ...                         ...    ...     ...        ...    ...
# 423  Volvo     C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo     C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                  S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                         V40  Wagon  Europe      Front  26135
# 427  Volvo                        XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.loc[cars.Origin.isin(['Europe','USA']),['Make','Model','Origin']]
# Out:
#       Make                       Model  Origin
# 7     Audi                 A4 1.8T 4dr  Europe
# 8     Audi      A41.8T convertible 2dr  Europe
# 9     Audi                  A4 3.0 4dr  Europe
# 10    Audi   A4 3.0 Quattro 4dr manual  Europe
# 11    Audi     A4 3.0 Quattro 4dr auto  Europe
# ..     ...                         ...     ...
# 423  Volvo     C70 LPT convertible 2dr  Europe
# 424  Volvo     C70 HPT convertible 2dr  Europe
# 425  Volvo                  S80 T6 4dr  Europe
# 426  Volvo                         V40  Europe
# 427  Volvo                        XC70  Europe
#
# [270 rows x 3 columns]

# %%
cars.Origin.unique()
# Out:
# array(['Asia', 'Europe', 'USA'], dtype=object)

# %%
cars.Origin.nunique()
# Out:
# 3

# %%
cars.loc[cars.Origin.isin(['Europe','USA']),['Make','Model','Origin']]

# %%
cars.Origin.str.upper().isin(['EUROPE','USA'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 423     True
# 424     True
# 425     True
# 426     True
# 427     True
# Name: Origin, Length: 428, dtype: bool

# %%
cars.loc[cars.Origin.str.upper().isin(['EUROPE','USA']),['Make','Model','Origin']]
# Out:
#       Make                       Model  Origin
# 7     Audi                 A4 1.8T 4dr  Europe
# 8     Audi      A41.8T convertible 2dr  Europe
# 9     Audi                  A4 3.0 4dr  Europe
# 10    Audi   A4 3.0 Quattro 4dr manual  Europe
# 11    Audi     A4 3.0 Quattro 4dr auto  Europe
# ..     ...                         ...     ...
# 423  Volvo     C70 LPT convertible 2dr  Europe
# 424  Volvo     C70 HPT convertible 2dr  Europe
# 425  Volvo                  S80 T6 4dr  Europe
# 426  Volvo                         V40  Europe
# 427  Volvo                        XC70  Europe
#
# [270 rows x 3 columns]

# %%
Task

Find the number of suspected outliers in Horsepower

# %%
q1 = cars.Horsepower.quantile(.25)
q3 = cars.Horsepower.quantile(.75)

u = q3 + (q3-q1)*1.5

l = q1 - (q3-q1)*1.5

# %%
u, l
# Out:
# (390.0, 30.0)

# %%
(cars.Horsepower > 390) | (cars.Horsepower < 30)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# Name: Horsepower, Length: 428, dtype: bool

# %%
((cars.Horsepower > 390) | (cars.Horsepower < 30)).sum()
# Out:
# 7

# %%
cars[(cars.Horsepower > 390) | (cars.Horsepower < 30)]
# Out:
#               Make                          Model    Type  Origin DriveTrain  \
# 20            Audi                       RS 6 4dr  Sports  Europe      Front
# 114          Dodge   Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 262  Mercedes-Benz                      CL600 2dr   Sedan  Europe       Rear
# 270  Mercedes-Benz                   SL55 AMG 2dr  Sports  Europe       Rear
# 271  Mercedes-Benz          SL600 convertible 2dr  Sports  Europe       Rear
# 334        Porsche                    911 GT2 2dr  Sports  Europe       Rear
# 412     Volkswagen                Phaeton W12 4dr   Sedan  Europe      Front
#
#        MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 20    84600    76417         4.2        8.0         450        15
# 114   81795    74451         8.3       10.0         500        12
# 262  128420   119600         5.5       12.0         493        13
# 270  121770   113388         5.5        8.0         493        14
# ...

# %%
cars[(cars.Horsepower > 390) | (cars.Horsepower < 30)].shape
# Out:
# (7, 15)

# %%
df = pd.DataFrame({'col1':['item'+str(i) for i in range(1,6)], 'col2': [23, 24, 28, 30, 32], 'col3': [98,92,94,91,90], 'col4': ['a', 'b', 'b', 'a', 'a']}, index = ['ind' + str(i) for i in range(5)])

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.select_dtypes(exclude = 'object')
# Out:
#       col2  col3
# ind0    23    98
# ind1    24    92
# ind2    28    94
# ind3    30    91
# ind4    32    90

# %%
df.select_dtypes(include = 'object')
# Out:
#        col1 col4
# ind0  item1    a
# ind1  item2    b
# ind2  item3    b
# ind3  item4    a
# ind4  item5    a

# %%
df.dtypes
# Out:
# col1    object
# col2     int64
# col3     int64
# col4    object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# col1     True
# col2    False
# col3    False
# col4     True
# dtype: bool

# %%
df.loc[:,df.dtypes == 'object']
# Out:
#        col1 col4
# ind0  item1    a
# ind1  item2    b
# ind2  item3    b
# ind3  item4    a
# ind4  item5    a

# %%
df_num = df.select_dtypes(exclude = 'object')

# %%
df_num
# Out:
#       col2  col3
# ind0    23    98
# ind1    24    92
# ind2    28    94
# ind3    30    91
# ind4    32    90

# %%
df_num>25
# Out:
#        col2  col3
# ind0  False  True
# ind1  False  True
# ind2   True  True
# ind3   True  True
# ind4   True  True

# %%
sum
any - Return whether any element is True, potentially over an axis
all - Return whether all elements are True, potentially over an axis

# %%
(df_num>25).sum(axis=1)
# Out:
# ind0    1
# ind1    1
# ind2    2
# ind3    2
# ind4    2
# dtype: int64

# %%
(df_num>25).sum(axis=0)
# Out:
# col2    3
# col3    5
# dtype: int64

# %%
df_num>25
# Out:
#        col2  col3
# ind0  False  True
# ind1  False  True
# ind2   True  True
# ind3   True  True
# ind4   True  True

# %%
(df_num>25).any(axis= 0)
# Out:
# col2    True
# col3    True
# dtype: bool

# %%
(df_num>25).all(axis= 0)
# Out:
# col2    False
# col3     True
# dtype: bool

# %%
(df_num>25).any(axis= 1)
# Out:
# ind0    True
# ind1    True
# ind2    True
# ind3    True
# ind4    True
# dtype: bool

# %%
(df_num>25).all(axis= 1)
# Out:
# ind0    False
# ind1    False
# ind2     True
# ind3     True
# ind4     True
# dtype: bool

# %%
df.isna()
# Out:
#        col1   col2   col3   col4
# ind0  False  False  False  False
# ind1  False  False  False  False
# ind2  False  False  False  False
# ind3  False  False  False  False
# ind4  False  False  False  False

# %%
cars.Cylinders.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# Name: Cylinders, Length: 428, dtype: bool

# %%
cars.Cylinders.isna().sum()
# Out:
# 2

# %%
cars.Cylinders.isna().any()
# Out:
# True

# %%
cars.Cylinders.isna().all()
# Out:
# False

# %%
Read train_tita.csv and provide a list of columns with any missing value in it

# %%
titanic = pd.read_csv("train_tita.csv")

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.isna().any(axis=0)
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.isna().any(axis=0)[titanic.isna().any(axis=0)==True].index
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic.columns[titanic.isna().any(axis=0)]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
Task:
    
subset titanic data for the rows where age of passenger is above avg
show me only those columns which dont have any missing value

# %%
titanic.isna().any(axis=0)
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.loc[titanic.Age>titanic.Age.mean(),~titanic.isna().any(axis=0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# 6                              McCarthy, Mr. Timothy J    male      0      0
# 11                            Bonnell, Miss. Elizabeth  female      0      0
# ...

# %%
cols = titanic.columns[~titanic.isna().any(axis=0)]
cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch',
#        'Ticket', 'Fare'],
#       dtype='object')

# %%
titanic.loc[titanic.Age>titanic.Age.mean(), cols]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# 6                              McCarthy, Mr. Timothy J    male      0      0
# 11                            Bonnell, Miss. Elizabeth  female      0      0
# ...

# %%
Task

Populate those records where there are no missing value in any column

# %%
titanic.isna().any(axis=1)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
~titanic.isna().any(axis=1)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Length: 891, dtype: bool

# %%
titanic[~titanic.isna().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[~titanic.isna().any(axis=1)].isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic[titanic.notna().all(axis=1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic.notna().all(axis=1)].isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Task

Tell me those columns which have more than 15% values missing

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(titanic.isna().sum()/titanic.shape[0])*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic.columns[(titanic.isna().sum()/titanic.shape[0])*100>15]
# Out:
# Index(['Age', 'Cabin'], dtype='object')

# %% [markdown]
# ## Working with duplicates

# %%
df = pd.DataFrame({'A':['kkk', 'kkk', 'kkk', 'jjj', 'kkk', 'kkk'],
                  'B':[0,1,1,1,0,0],
                  'C':['S','S','T','S','S','S']})

# %%
df
# Out:
#      A  B  C
# 0  kkk  0  S
# 1  kkk  1  S
# 2  kkk  1  T
# 3  jjj  1  S
# 4  kkk  0  S
# 5  kkk  0  S

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.duplicated(keep = 'first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df.duplicated(keep = 'last')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df.duplicated(keep = False)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df.duplicated(keep = False).sum()
# Out:
# 3

# %%
df[df.duplicated(keep = False)]
# Out:
#      A  B  C
# 0  kkk  0  S
# 4  kkk  0  S
# 5  kkk  0  S

# %%
df.drop_duplicates()
# Out:
#      A  B  C
# 0  kkk  0  S
# 1  kkk  1  S
# 2  kkk  1  T
# 3  jjj  1  S

# %%
df
# Out:
#      A  B  C
# 0  kkk  0  S
# 1  kkk  1  S
# 2  kkk  1  T
# 3  jjj  1  S
# 4  kkk  0  S
# 5  kkk  0  S

# %%
df.duplicated(['A','C'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
df = pd.DataFrame({'year':[i for i in range(2010, 2021)]+[2015],
                  'Emp_ID':['emp'+str(i) for i in range(11)]+['emp5'],
                  'Ratings':[4,3,2,1,5,7,8,7,8,6,9,2]})

# %%
df  # top performer of various years
# Out:
#     year Emp_ID  Ratings
# 0   2010   emp0        4
# 1   2011   emp1        3
# 2   2012   emp2        2
# 3   2013   emp3        1
# 4   2014   emp4        5
# 5   2015   emp5        7
# 6   2016   emp6        8
# 7   2017   emp7        7
# 8   2018   emp8        8
# 9   2019   emp9        6
# 10  2020  emp10        9
# 11  2015   emp5        2

# %%
Hr tells you that there are 11 employees

# %%
df.shape
# Out:
# (12, 3)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
df.year.nunique()
# Out:
# 11

# %%
df.Emp_ID.nunique()
# Out:
# 11

# %%
df.duplicated(['year','Emp_ID'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %%
df.duplicated(['year','Emp_ID']).sum()
# Out:
# 1

# %%
df.duplicated(['year','Emp_ID'], keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %%
df[df.duplicated(['year','Emp_ID'], keep=False)]
# Out:
#     year Emp_ID  Ratings
# 5   2015   emp5        7
# 11  2015   emp5        2

# %%
df = pd.DataFrame({'A':['kkk', 'kkk', 'kkk', 'jjj', 'kkk', 'kkk'],
                  'B':[0,1,1,1,0,0],
                  'C':['S','S','T','S','S','S']})

# %%
df
# Out:
#      A  B  C
# 0  kkk  0  S
# 1  kkk  1  S
# 2  kkk  1  T
# 3  jjj  1  S
# 4  kkk  0  S
# 5  kkk  0  S

# %%
cars
# Out:
#       Make                     Model   Type  Origin DriveTrain   MSRP  \
# 0    Acura                       MDX    SUV    Asia        All  36945
# 1    Acura            RSX Type S 2dr  Sedan    Asia      Front  23820
# 2    Acura                   TSX 4dr  Sedan    Asia      Front  26990
# 3    Acura                    TL 4dr  Sedan    Asia      Front  33195
# 4    Acura                3.5 RL 4dr  Sedan    Asia      Front  43755
# ..     ...                       ...    ...     ...        ...    ...
# 423  Volvo   C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo   C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                       V40  Wagon  Europe      Front  26135
# 427  Volvo                      XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
highest MSRP for each region for each type of car

# %%
cars_sorted = cars.sort_values(by = ['Origin','Type','MSRP'], ascending = [True, True, False])

# %%
cars_sorted
# Out:
#           Make                                    Model    Type Origin  \
# 373     Toyota                 Prius 4dr (gas/electric)  Hybrid   Asia
# 149      Honda   Civic Hybrid 4dr manual (gas/electric)  Hybrid   Asia
# 150      Honda               Insight 2dr (gas/electric)  Hybrid   Asia
# 219      Lexus                                   LX 470     SUV   Asia
# 377     Toyota                             Land Cruiser     SUV   Asia
# ..         ...                                      ...     ...    ...
# 285    Mercury                                 Sable GS   Wagon    USA
# 140       Ford                                Taurus SE   Wagon    USA
# 89   Chevrolet                           Malibu Maxx LS   Wagon    USA
# 139       Ford                                Focus ZTW   Wagon    USA
# 329    Pontiac                                     Vibe   Wagon    USA
#
#     DriveTrain   MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# ...

# %%
cars.loc[~(cars_sorted.duplicated(['Origin','Type'], keep='first')), ['Origin','Type','MSRP']]
# Out:
#      Origin    Type    MSRP
# 6      Asia  Sports   89765
# 55      USA     SUV   52795
# 59      USA   Sedan   50595
# 62      USA   Truck   52975
# 104     USA   Wagon   31230
# 114     USA  Sports   81795
# 186    Asia   Wagon   36395
# 219    Asia     SUV   64800
# 226    Asia   Sedan   55750
# 251  Europe     SUV   76870
# 262  Europe   Sedan  128420
# 276  Europe   Wagon   60670
# 314    Asia   Truck   26650
# 334  Europe  Sports  192465
# 373    Asia  Hybrid   20510

# %%
cars.loc[~(cars_sorted.duplicated(['Origin','Type'], keep='last')), ['Origin','Type','MSRP']]
# Out:
#      Origin    Type   MSRP
# 43   Europe  Sports  33895
# 133     USA  Sports  18345
# 138     USA   Truck  14385
# 150    Asia  Hybrid  19110
# 178    Asia  Sports  18739
# 202     USA     SUV  20130
# 206    Asia   Sedan  10280
# 214    Asia   Wagon  11905
# 217  Europe     SUV  25995
# 238  Europe   Sedan  16999
# 329     USA   Wagon  17045
# 345     USA   Sedan  10995
# 366    Asia     SUV  17163
# 397    Asia   Truck  12800
# 413  Europe   Wagon  19005

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Find out passenger IDs and names of oldest female passengers Embarked from different locations

# %%
titanic_sorted = titanic.sort_values(by = ['Embarked','Sex', 'Age'], ascending = [True, False, False])

# %%
titanic_sorted.duplicated(['Embarked','Sex'], keep='first')
# Out:
# 96     False
# 493     True
# 54      True
# 587     True
# 487     True
#        ...
# 792     True
# 863     True
# 888     True
# 829    False
# 61      True
# Length: 891, dtype: bool

# %%
titanic_m_f = titanic.loc[~titanic_sorted.duplicated(['Embarked','Sex'], keep='first'),['PassengerId','Name','Age', 'Sex','Embarked']]

# %%
titanic_m_f[titanic_m_f.Sex=='female']
# Out:
#      PassengerId                                              Name   Age  \
# 275          276                 Andrews, Miss. Kornelia Theodosia  63.0
# 366          367  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0
# 829          830         Stone, Mrs. George Nelson (Martha Evelyn)  62.0
# 885          886              Rice, Mrs. William (Margaret Norton)  39.0
#
#         Sex Embarked
# 275  female        S
# 366  female        C
# 829  female      NaN
# 885  female        Q

# %%
df = pd.DataFrame({'col1':['item'+str(i) for i in range(1,6)], 'col2': [23, 24, 28, 30, 32], 'col3': [98,92,94,91,90], 'col4': ['a', 'b', 'b', 'a', 'a']}, index = ['ind' + str(i) for i in range(5)])

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.sort_values(by=['col2'], ascending=True)
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.sort_values(by=['col2'], ascending=False)
# Out:
#        col1  col2  col3 col4
# ind4  item5    32    90    a
# ind3  item4    30    91    a
# ind2  item3    28    94    b
# ind1  item2    24    92    b
# ind0  item1    23    98    a

# %%
df.sort_values(by = ['col4', 'col2'], ascending = [True, False])
# Out:
#        col1  col2  col3 col4
# ind4  item5    32    90    a
# ind3  item4    30    91    a
# ind0  item1    23    98    a
# ind2  item3    28    94    b
# ind1  item2    24    92    b

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.sort_values(by = ['col4', 'col2'], ascending = [True, False], inplace=True)

# %%
df
# Out:
#        col1  col2  col3 col4
# ind4  item5    32    90    a
# ind3  item4    30    91    a
# ind0  item1    23    98    a
# ind2  item3    28    94    b
# ind1  item2    24    92    b

# %%
# To get fresh indices

df.reset_index()
# Out:
#   index   col1  col2  col3 col4
# 0  ind4  item5    32    90    a
# 1  ind3  item4    30    91    a
# 2  ind0  item1    23    98    a
# 3  ind2  item3    28    94    b
# 4  ind1  item2    24    92    b

# %%
# previous indices are retained in a column called 'index'

# if we want to remove this column

df.reset_index(drop=True)
# Out:
#     col1  col2  col3 col4
# 0  item5    32    90    a
# 1  item4    30    91    a
# 2  item1    23    98    a
# 3  item3    28    94    b
# 4  item2    24    92    b

# %%
df = pd.DataFrame({'col1':['item'+str(i) for i in range(1,6)], 'col2': [23, 24, 28, 30, 32], 'col3': [98,92,94,91,90], 'col4': ['a', 'b', 'b', 'a', 'a']}, index = ['ind' + str(i) for i in range(5)])

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
# After sorting the data inplace, what if we want original data back

df.sort_values(by = 'col3', ascending = True, inplace=True)

# %%
df
# Out:
#        col1  col2  col3 col4
# ind4  item5    32    90    a
# ind3  item4    30    91    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind0  item1    23    98    a

# %%
df.sort_index()
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df
# Out:
#        col1  col2  col3 col4
# ind4  item5    32    90    a
# ind3  item4    30    91    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind0  item1    23    98    a

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %% [markdown]
# ## Renaming rows and columns

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.rename(columns = {'col1':'items', 'col3': 'col 90+'})
# Out:
#       items  col2  col 90+ col4
# ind0  item1    23       98    a
# ind1  item2    24       92    b
# ind2  item3    28       94    b
# ind3  item4    30       91    a
# ind4  item5    32       90    a

# %%
df
# Out:
#        col1  col2  col3 col4
# ind0  item1    23    98    a
# ind1  item2    24    92    b
# ind2  item3    28    94    b
# ind3  item4    30    91    a
# ind4  item5    32    90    a

# %%
df.rename(columns = {'col1':'items', 'col3': 'col 90+'}, inplace=True)

# %%
df
# Out:
#       items  col2  col 90+ col4
# ind0  item1    23       98    a
# ind1  item2    24       92    b
# ind2  item3    28       94    b
# ind3  item4    30       91    a
# ind4  item5    32       90    a

# %%
# import numpy as np
# df.iloc[3,2] = np.nan

# %%
df
# Out:
#       items  col2  col 90+ col4
# ind0  item1    23     98.0    a
# ind1  item2    24     92.0    b
# ind2  item3    28     94.0    b
# ind3  item4    30      NaN    a
# ind4  item5    32     90.0    a

# %%
df.rename(columns = {'col2': 'col 30-', 'col4': 'segments'})
# Out:
#       items  col 30-  col 90+ segments
# ind0  item1       23     98.0        a
# ind1  item2       24     92.0        b
# ind2  item3       28     94.0        b
# ind3  item4       30      NaN        a
# ind4  item5       32     90.0        a

# %%
df.rename({'col2': 'col 30-', 'col4': 'segments'}, axis=1)
# Out:
#       items  col 30-  col 90+ segments
# ind0  item1       23     98.0        a
# ind1  item2       24     92.0        b
# ind2  item3       28     94.0        b
# ind3  item4       30      NaN        a
# ind4  item5       32     90.0        a

# %%
df
# Out:
#       items  col2  col 90+ col4
# ind0  item1    23     98.0    a
# ind1  item2    24     92.0    b
# ind2  item3    28     94.0    b
# ind3  item4    30      NaN    a
# ind4  item5    32     90.0    a

# %%
df.columns = ['item descr', 'Less Than 30', 'More Than 90', 'segments']

# %%
df
# Out:
#      item descr  Less Than 30  More Than 90 segments
# ind0      item1            23          98.0        a
# ind1      item2            24          92.0        b
# ind2      item3            28          94.0        b
# ind3      item4            30           NaN        a
# ind4      item5            32          90.0        a

# %%
df
# Out:
#      item descr  Less Than 30  More Than 90 segments
# ind0      item1            23          98.0        a
# ind1      item2            24          92.0        b
# ind2      item3            28          94.0        b
# ind3      item4            30           NaN        a
# ind4      item5            32          90.0        a

# %%
df.columns.str.replace(' ','_')
# Out:
# Index(['item_descr', 'Less_Than_30', 'More_Than_90', 'segments'], dtype='object')

# %%
df.rename(index={'ind0':'index 0'})
# Out:
#         item descr  Less Than 30  More Than 90 segments
# index 0      item1            23          98.0        a
# ind1         item2            24          92.0        b
# ind2         item3            28          94.0        b
# ind3         item4            30           NaN        a
# ind4         item5            32          90.0        a

# %%
df.rename({'ind0':'index 0'}, axis=0)
# Out:
#         item descr  Less Than 30  More Than 90 segments
# index 0      item1            23          98.0        a
# ind1         item2            24          92.0        b
# ind2         item3            28          94.0        b
# ind3         item4            30           NaN        a
# ind4         item5            32          90.0        a

# %% [markdown]
# ## Aggregation

# %%
cars.groupby('Origin').mean()
# Out:
#                 MSRP       Invoice  EngineSize  Cylinders  Horsepower  \
# Origin
# Asia    24741.322785  22602.177215    2.774051   5.185897  190.702532
# Europe  48349.796748  44395.081301    3.206504   6.235772  251.894309
# USA     28377.442177  25949.340136    3.642857   6.108844  212.823129
#
#          MPG_City  MPG_Highway       Weight   Wheelbase      Length
# Origin
# Asia    22.012658    28.265823  3319.316456  105.886076  182.816456
# Europe  18.731707    26.008130  3680.723577  106.447154  181.845528
# USA     19.074830    26.013605  3769.952381  112.020408  193.952381

# %%
cars.groupby('Origin')['MSRP'].mean()
# Out:
# Origin
# Asia      24741.322785
# Europe    48349.796748
# USA       28377.442177
# Name: MSRP, dtype: float64

# %%
cars.groupby('Origin')[['MSRP']].mean()
# Out:
#                 MSRP
# Origin
# Asia    24741.322785
# Europe  48349.796748
# USA     28377.442177

# %%
cars.groupby('Origin')[['MSRP','Horsepower']].mean()
# Out:
#                 MSRP  Horsepower
# Origin
# Asia    24741.322785  190.702532
# Europe  48349.796748  251.894309
# USA     28377.442177  212.823129

# %%
Task

find out the average, min and maximum age of males and females of different passenger classes

# %%
titanic.groupby(['Pclass','Sex'])[['Age']].min()
# Out:
#                 Age
# Pclass Sex
# 1      female  2.00
#        male    0.92
# 2      female  2.00
#        male    0.67
# 3      female  0.75
#        male    0.42

# %%
titanic.groupby(['Pclass','Sex'])[['Age']].max()
# Out:
#                 Age
# Pclass Sex
# 1      female  63.0
#        male    80.0
# 2      female  57.0
#        male    70.0
# 3      female  63.0
#        male    74.0

# %%
titanic.groupby(['Pclass','Sex'])[['Age']].mean()
# Out:
#                      Age
# Pclass Sex
# 1      female  34.611765
#        male    41.281386
# 2      female  28.722973
#        male    30.740707
# 3      female  21.750000
#        male    26.507589

# %%
titanic.groupby(['Pclass','Sex'])[['Age']].agg(['min','max','mean'])
# Out:
#                 Age
#                 min   max       mean
# Pclass Sex
# 1      female  2.00  63.0  34.611765
#        male    0.92  80.0  41.281386
# 2      female  2.00  57.0  28.722973
#        male    0.67  70.0  30.740707
# 3      female  0.75  63.0  21.750000
#        male    0.42  74.0  26.507589

# %%
titanic.sort_values(by=['Embarked','Age'], ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 803          804         1       3            Thomas, Master. Assad Alexander
# 469          470         1       3              Baclini, Miss. Helene Barbara
# 644          645         1       3                     Baclini, Miss. Eugenie
# 381          382         1       3                Nakid, Miss. Maria ("Mary")
# 827          828         1       2                      Mallet, Master. Andre
# ..           ...       ...     ...                                        ...
# 868          869         0       3                van Melkebeke, Mr. Philemon
# 878          879         0       3                         Laleff, Mr. Kristo
# 888          889         0       3   Johnston, Miss. Catherine Helen "Carrie"
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
# ...

# %%
Find out smallest 5 age values for the passengers embarked from different locations

# %%
titanic.Embarked.unique()
# Out:
# array(['C', 'Q', 'S', nan], dtype=object)

# %%
titanic.sort_values(by=['Embarked','Age'], ascending=[True,True], inplace=True)

# %%
titanic.groupby('Embarked').head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 827          828         1       2            Mallet, Master. Andre    male
# 16            17         0       3             Rice, Master. Eugene    male
# 171          172         0       3             Rice, Master. Arthur    male
# 278          279         0       3               Rice, Master. Eric    male
# 787          788         0       3        Rice, Master. George Hugh    male
# 22            23         1       3      McGowan, Miss. Anna "Annie"  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# ...

# %%
Task

Find out top 3 cars of different Makes according to Horsepower from different origins

# %%
cars.sort_values(by = ['Origin', 'Make', 'Horsepower'], ascending = [True, True, False], inplace=True)

# %%
cars.groupby(['Origin','Make']).head(3)
# Out:
#         Make                    Model    Type Origin DriveTrain   MSRP  \
# 6      Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  89765
# 3      Acura                   TL 4dr   Sedan   Asia      Front  33195
# 0      Acura                      MDX     SUV   Asia        All  36945
# 151    Honda                 Pilot LX     SUV   Asia        All  27560
# 161    Honda         Accord LX V6 4dr   Sedan   Asia      Front  23760
# ..       ...                      ...     ...    ...        ...    ...
# 325  Pontiac       Bonneville GXP 4dr   Sedan    USA      Front  35995
# 322  Pontiac       Grand Prix GT1 4dr   Sedan    USA      Front  22395
# 350   Saturn               L300-2 4dr   Sedan    USA      Front  21410
# 344   Saturn                      VUE     SUV    USA        All  20585
# 345   Saturn                 Ion1 4dr   Sedan    USA      Front  10995
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
titanic.groupby(['Pclass','Sex'])[['Age','Pclass']].agg({'Age':['mean'],'Pclass':['count']})
# Out:
#                      Age Pclass
#                     mean  count
# Pclass Sex
# 1      female  34.611765     94
#        male    41.281386    122
# 2      female  28.722973     76
#        male    30.740707    108
# 3      female  21.750000    144
#        male    26.507589    347

# %%
Task

Find the number of male-kids passengers in titanic 

#embarked from different locations

Hint: To identify male kids - check the names - the salutation is "Master"

# %%
titanic.Name.str.contains('Master')
# Out:
# 803     True
# 469    False
# 644    False
# 381    False
# 827     True
#        ...
# 868    False
# 878    False
# 888    False
# 61     False
# 829    False
# Name: Name, Length: 891, dtype: bool

# %%
titanic.Name.str.contains('Master').sum()
# Out:
# 40

# %%
titanic[titanic.Name.str.contains('Master')].groupby('Embarked')['PassengerId'].count()
# Out:
# Embarked
# C     5
# Q     4
# S    31
# Name: PassengerId, dtype: int64

# %%
titanic[titanic.Name.str.contains('Master')]['Embarked'].value_counts()
# Out:
# S    31
# C     5
# Q     4
# Name: Embarked, dtype: int64

# %%
titanic[titanic.Name.str.find('Master')>=0]['Embarked'].value_counts()
# Out:
# S    31
# C     5
# Q     4
# Name: Embarked, dtype: int64

# %%
## user defined function in groupby

# %%
titanic.groupby(['Pclass','Sex'])[['Age','Pclass']].agg({'Age':['mean'],'Pclass':['count']})

# %%
For Age find the range

range = max - min

# %%
Task

Create a user defined function to find the range of a series

Use the function for aggregation using groupby

# %%
def cal_range(x):
    
    return x.max() - x.min()

# %%
cal_range(cars.Horsepower)
# Out:
# 427

# %%
titanic.groupby(['Pclass','Sex'])[['Age','Pclass']].agg({'Age':[cal_range],'Pclass':['count']})
# Out:
#                     Age Pclass
#               cal_range  count
# Pclass Sex
# 1      female     61.00     94
#        male       79.08    122
# 2      female     55.00     76
#        male       69.33    108
# 3      female     62.25    144
#        male       73.58    347

# %%
titanic_groupby = titanic.groupby(['Pclass','Sex'])[['Age','Pclass']].agg({'Age':[cal_range],'Pclass':['count']})

# %%
titanic_groupby
# Out:
#                     Age Pclass
#               cal_range  count
# Pclass Sex
# 1      female     61.00     94
#        male       79.08    122
# 2      female     55.00     76
#        male       69.33    108
# 3      female     62.25    144
#        male       73.58    347

# %%
titanic_groupby.columns
# Out:
# MultiIndex([(   'Age', 'cal_range'),
#             ('Pclass',     'count')],
#            )

# %%
titanic_groupby.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])

# %%
This is multi-index data

Now extract the information for 

females of passenger class 1 & 3, and males of passenger class 2

Use: loc or iloc

# %%
titanic_groupby.loc[[(1, 'female'),(3, 'female'),(2,   'male')],[(   'Age', 'cal_range')]]
# Out:
#                     Age
#               cal_range
# Pclass Sex
# 1      female     61.00
# 3      female     62.25
# 2      male       69.33

# %%
Use iloc to get the same result

# %%
print(titanic_groupby.index)
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])

# %%
titanic_groupby.iloc[[0,4,3],[0]]
# Out:
#                     Age
#               cal_range
# Pclass Sex
# 1      female     61.00
# 3      female     62.25
# 2      male       69.33
